# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Layer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.initializers import Constant
from matplotlib import pyplot as plt

# %% [markdown]
# #### Importo il dataset

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(path="mnist.npz")

# %% [markdown]
# #### Pre-processing

# %%
train_images = (train_images / 255)
test_images = (test_images / 255)

train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# #### Creo una funzione per generare un blocco con architettura highway che mi consente di implementare una grande quantita di layers e evitare esplosione o svanimento del gradiente

# %%
def get_higway_block(input):
    H = Dense(8, activation = 'swish')(input)
    T = Dense(8, activation = 'sigmoid', bias_initializer = Constant(-10))(input)
    return H * T + input * (1 - T)

input = Input(shape=(train_images.shape[1:]))

dense = Dense(8, activation = 'swish')(input)
highway = get_higway_block(dense)
for i in range(200):
    highway = get_higway_block(highway)

output = Dense(10, activation = 'softmax')(highway)

model = Model(input, output)
model.compile(loss = 'categorical_crossentropy', optimizer= Adam(), metrics = 'accuracy')
model.summary()

print(len(model.layers), 'layers')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 784)]                0         []
#
#  dense (Dense)               (None, 8)                    6280      ['input_1[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    72        ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 8)                    72        ['dense[0][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 8)                    0         ['dense_2[0][0]']
#  da)
#
#  tf.math.multiply (TFOpLamb  (None, 8)                    0         ['dense_1[0][0]',
#  da)                                                                 'dense_2[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 8)                    0         ['dense[0][0]',
#  mbda)                                                               'tf.math.subtract[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 8)                    0         ['tf.math.multiply[0][0]',
#  Lambda)                                                             'tf.math.multiply_1[0][0]']
#
#  dense_4 (Dense)             (None, 8)                    72        ['tf.__operators__.add[0][0]']
#
#  dense_3 (Dense)             (None, 8)                    72        ['tf.__operators__.add[0][0]']
#
#  tf.math.subtract_1 (TFOpLa  (None, 8)                    0         ['dense_4[0][0]']
#  mbda)
#
#  tf.math.multiply_2 (TFOpLa  (None, 8)                    0         ['dense_3[0][0]',
#  mbda)                                                               'dense_4[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 8)                    0         ['tf.__operators__.add[0][0]',
#  mbda)                                                               'tf.math.subtract_1[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 8)                    0         ['tf.math.multiply_2[0][0]',
#  OpLambda)                                                           'tf.math.multiply_3[0][0]']
#
#  dense_6 (Dense)             (None, 8)                    72        ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 8)                    72        ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.math.subtract_2 (TFOpLa  (None, 8)                    0         ['dense_6[0][0]']
#  mbda)
#
#  tf.math.multiply_4 (TFOpLa  (None, 8)                    0         ['dense_5[0][0]',
#  mbda)                                                               'dense_6[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  (None, 8)                    0         ['tf.__operators__.add_1[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.subtract_2[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 8)                    0         ['tf.math.multiply_4[0][0]',
#  OpLambda)                                                           'tf.math.multiply_5[0][0]']
#
#  dense_8 (Dense)             (None, 8)                    72        ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 8)                    72        ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  tf.math.subtract_3 (TFOpLa  (None, 8)                    0         ['dense_8[0][0]']
#  mbda)
#
#  tf.math.multiply_6 (TFOpLa  (None, 8)                    0         ['dense_7[0][0]',
#  mbda)                                                               'dense_8[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  (None, 8)                    0         ['tf.__operators__.add_2[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.subtract_3[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 8)                    0         ['tf.math.multiply_6[0][0]',
#  OpLambda)                                                           'tf.math.multiply_7[0][0]']
#
#  dense_10 (Dense)            (None, 8)                    72        ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dense_9 (Dense)             (None, 8)                    72        ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  tf.math.subtract_4 (TFOpLa  (None, 8)                    0         ['dense_10[0][0]']
#  mbda)
#
#  tf.math.multiply_8 (TFOpLa  (None, 8)                    0         ['dense_9[0][0]',
#  mbda)                                                               'dense_10[0][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 8)                    0         ['tf.__operators__.add_3[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.subtract_4[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 8)                    0         ['tf.math.multiply_8[0][0]',
#  OpLambda)                                                           'tf.math.multiply_9[0][0]']
#
#  dense_12 (Dense)            (None, 8)                    72        ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  dense_11 (Dense)            (None, 8)                    72        ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  tf.math.subtract_5 (TFOpLa  (None, 8)                    0         ['dense_12[0][0]']
#  mbda)
#
#  tf.math.multiply_10 (TFOpL  (None, 8)                    0         ['dense_11[0][0]',
#  ambda)                                                              'dense_12[0][0]']
#
#  tf.math.multiply_11 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_4[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.subtract_5[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 8)                    0         ['tf.math.multiply_10[0][0]',
#  OpLambda)                                                           'tf.math.multiply_11[0][0]']
#
#  dense_14 (Dense)            (None, 8)                    72        ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dense_13 (Dense)            (None, 8)                    72        ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  tf.math.subtract_6 (TFOpLa  (None, 8)                    0         ['dense_14[0][0]']
#  mbda)
#
#  tf.math.multiply_12 (TFOpL  (None, 8)                    0         ['dense_13[0][0]',
#  ambda)                                                              'dense_14[0][0]']
#
#  tf.math.multiply_13 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_5[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.subtract_6[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 8)                    0         ['tf.math.multiply_12[0][0]',
#  OpLambda)                                                           'tf.math.multiply_13[0][0]']
#
#  dense_16 (Dense)            (None, 8)                    72        ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  dense_15 (Dense)            (None, 8)                    72        ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  tf.math.subtract_7 (TFOpLa  (None, 8)                    0         ['dense_16[0][0]']
#  mbda)
#
#  tf.math.multiply_14 (TFOpL  (None, 8)                    0         ['dense_15[0][0]',
#  ambda)                                                              'dense_16[0][0]']
#
#  tf.math.multiply_15 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_6[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.subtract_7[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 8)                    0         ['tf.math.multiply_14[0][0]',
#  OpLambda)                                                           'tf.math.multiply_15[0][0]']
#
#  dense_18 (Dense)            (None, 8)                    72        ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  dense_17 (Dense)            (None, 8)                    72        ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  tf.math.subtract_8 (TFOpLa  (None, 8)                    0         ['dense_18[0][0]']
#  mbda)
#
#  tf.math.multiply_16 (TFOpL  (None, 8)                    0         ['dense_17[0][0]',
#  ambda)                                                              'dense_18[0][0]']
#
#  tf.math.multiply_17 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_7[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.subtract_8[0][0]']
#
#  tf.__operators__.add_8 (TF  (None, 8)                    0         ['tf.math.multiply_16[0][0]',
#  OpLambda)                                                           'tf.math.multiply_17[0][0]']
#
#  dense_20 (Dense)            (None, 8)                    72        ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  dense_19 (Dense)            (None, 8)                    72        ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  tf.math.subtract_9 (TFOpLa  (None, 8)                    0         ['dense_20[0][0]']
#  mbda)
#
#  tf.math.multiply_18 (TFOpL  (None, 8)                    0         ['dense_19[0][0]',
#  ambda)                                                              'dense_20[0][0]']
#
#  tf.math.multiply_19 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_8[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.subtract_9[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 8)                    0         ['tf.math.multiply_18[0][0]',
#  OpLambda)                                                           'tf.math.multiply_19[0][0]']
#
#  dense_22 (Dense)            (None, 8)                    72        ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  dense_21 (Dense)            (None, 8)                    72        ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  tf.math.subtract_10 (TFOpL  (None, 8)                    0         ['dense_22[0][0]']
#  ambda)
#
#  tf.math.multiply_20 (TFOpL  (None, 8)                    0         ['dense_21[0][0]',
#  ambda)                                                              'dense_22[0][0]']
#
#  tf.math.multiply_21 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_9[0][0]
#  ambda)                                                             ',
#                                                                      'tf.math.subtract_10[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 8)                    0         ['tf.math.multiply_20[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_21[0][0]']
#
#  dense_24 (Dense)            (None, 8)                    72        ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  dense_23 (Dense)            (None, 8)                    72        ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.subtract_11 (TFOpL  (None, 8)                    0         ['dense_24[0][0]']
#  ambda)
#
#  tf.math.multiply_22 (TFOpL  (None, 8)                    0         ['dense_23[0][0]',
#  ambda)                                                              'dense_24[0][0]']
#
#  tf.math.multiply_23 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_10[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_11[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 8)                    0         ['tf.math.multiply_22[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_23[0][0]']
#
#  dense_26 (Dense)            (None, 8)                    72        ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  dense_25 (Dense)            (None, 8)                    72        ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  tf.math.subtract_12 (TFOpL  (None, 8)                    0         ['dense_26[0][0]']
#  ambda)
#
#  tf.math.multiply_24 (TFOpL  (None, 8)                    0         ['dense_25[0][0]',
#  ambda)                                                              'dense_26[0][0]']
#
#  tf.math.multiply_25 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_11[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_12[0][0]']
#
#  tf.__operators__.add_12 (T  (None, 8)                    0         ['tf.math.multiply_24[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_25[0][0]']
#
#  dense_28 (Dense)            (None, 8)                    72        ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  dense_27 (Dense)            (None, 8)                    72        ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  tf.math.subtract_13 (TFOpL  (None, 8)                    0         ['dense_28[0][0]']
#  ambda)
#
#  tf.math.multiply_26 (TFOpL  (None, 8)                    0         ['dense_27[0][0]',
#  ambda)                                                              'dense_28[0][0]']
#
#  tf.math.multiply_27 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_12[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_13[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 8)                    0         ['tf.math.multiply_26[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_27[0][0]']
#
#  dense_30 (Dense)            (None, 8)                    72        ['tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  dense_29 (Dense)            (None, 8)                    72        ['tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  tf.math.subtract_14 (TFOpL  (None, 8)                    0         ['dense_30[0][0]']
#  ambda)
#
#  tf.math.multiply_28 (TFOpL  (None, 8)                    0         ['dense_29[0][0]',
#  ambda)                                                              'dense_30[0][0]']
#
#  tf.math.multiply_29 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_13[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_14[0][0]']
#
#  tf.__operators__.add_14 (T  (None, 8)                    0         ['tf.math.multiply_28[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_29[0][0]']
#
#  dense_32 (Dense)            (None, 8)                    72        ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  dense_31 (Dense)            (None, 8)                    72        ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  tf.math.subtract_15 (TFOpL  (None, 8)                    0         ['dense_32[0][0]']
#  ambda)
#
#  tf.math.multiply_30 (TFOpL  (None, 8)                    0         ['dense_31[0][0]',
#  ambda)                                                              'dense_32[0][0]']
#
#  tf.math.multiply_31 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_14[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_15[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 8)                    0         ['tf.math.multiply_30[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_31[0][0]']
#
#  dense_34 (Dense)            (None, 8)                    72        ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  dense_33 (Dense)            (None, 8)                    72        ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  tf.math.subtract_16 (TFOpL  (None, 8)                    0         ['dense_34[0][0]']
#  ambda)
#
#  tf.math.multiply_32 (TFOpL  (None, 8)                    0         ['dense_33[0][0]',
#  ambda)                                                              'dense_34[0][0]']
#
#  tf.math.multiply_33 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_15[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_16[0][0]']
#
#  tf.__operators__.add_16 (T  (None, 8)                    0         ['tf.math.multiply_32[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_33[0][0]']
#
#  dense_36 (Dense)            (None, 8)                    72        ['tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  dense_35 (Dense)            (None, 8)                    72        ['tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  tf.math.subtract_17 (TFOpL  (None, 8)                    0         ['dense_36[0][0]']
#  ambda)
#
#  tf.math.multiply_34 (TFOpL  (None, 8)                    0         ['dense_35[0][0]',
#  ambda)                                                              'dense_36[0][0]']
#
#  tf.math.multiply_35 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_16[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_17[0][0]']
#
#  tf.__operators__.add_17 (T  (None, 8)                    0         ['tf.math.multiply_34[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_35[0][0]']
#
#  dense_38 (Dense)            (None, 8)                    72        ['tf.__operators__.add_17[0][0
#                                                                     ]']
#
#  dense_37 (Dense)            (None, 8)                    72        ['tf.__operators__.add_17[0][0
#                                                                     ]']
#
#  tf.math.subtract_18 (TFOpL  (None, 8)                    0         ['dense_38[0][0]']
#  ambda)
#
#  tf.math.multiply_36 (TFOpL  (None, 8)                    0         ['dense_37[0][0]',
#  ambda)                                                              'dense_38[0][0]']
#
#  tf.math.multiply_37 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_17[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_18[0][0]']
#
#  tf.__operators__.add_18 (T  (None, 8)                    0         ['tf.math.multiply_36[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_37[0][0]']
#
#  dense_40 (Dense)            (None, 8)                    72        ['tf.__operators__.add_18[0][0
#                                                                     ]']
#
#  dense_39 (Dense)            (None, 8)                    72        ['tf.__operators__.add_18[0][0
#                                                                     ]']
#
#  tf.math.subtract_19 (TFOpL  (None, 8)                    0         ['dense_40[0][0]']
#  ambda)
#
#  tf.math.multiply_38 (TFOpL  (None, 8)                    0         ['dense_39[0][0]',
#  ambda)                                                              'dense_40[0][0]']
#
#  tf.math.multiply_39 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_18[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_19[0][0]']
#
#  tf.__operators__.add_19 (T  (None, 8)                    0         ['tf.math.multiply_38[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_39[0][0]']
#
#  dense_42 (Dense)            (None, 8)                    72        ['tf.__operators__.add_19[0][0
#                                                                     ]']
#
#  dense_41 (Dense)            (None, 8)                    72        ['tf.__operators__.add_19[0][0
#                                                                     ]']
#
#  tf.math.subtract_20 (TFOpL  (None, 8)                    0         ['dense_42[0][0]']
#  ambda)
#
#  tf.math.multiply_40 (TFOpL  (None, 8)                    0         ['dense_41[0][0]',
#  ambda)                                                              'dense_42[0][0]']
#
#  tf.math.multiply_41 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_19[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_20[0][0]']
#
#  tf.__operators__.add_20 (T  (None, 8)                    0         ['tf.math.multiply_40[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_41[0][0]']
#
#  dense_44 (Dense)            (None, 8)                    72        ['tf.__operators__.add_20[0][0
#                                                                     ]']
#
#  dense_43 (Dense)            (None, 8)                    72        ['tf.__operators__.add_20[0][0
#                                                                     ]']
#
#  tf.math.subtract_21 (TFOpL  (None, 8)                    0         ['dense_44[0][0]']
#  ambda)
#
#  tf.math.multiply_42 (TFOpL  (None, 8)                    0         ['dense_43[0][0]',
#  ambda)                                                              'dense_44[0][0]']
#
#  tf.math.multiply_43 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_20[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_21[0][0]']
#
#  tf.__operators__.add_21 (T  (None, 8)                    0         ['tf.math.multiply_42[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_43[0][0]']
#
#  dense_46 (Dense)            (None, 8)                    72        ['tf.__operators__.add_21[0][0
#                                                                     ]']
#
#  dense_45 (Dense)            (None, 8)                    72        ['tf.__operators__.add_21[0][0
#                                                                     ]']
#
#  tf.math.subtract_22 (TFOpL  (None, 8)                    0         ['dense_46[0][0]']
#  ambda)
#
#  tf.math.multiply_44 (TFOpL  (None, 8)                    0         ['dense_45[0][0]',
#  ambda)                                                              'dense_46[0][0]']
#
#  tf.math.multiply_45 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_21[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_22[0][0]']
#
#  tf.__operators__.add_22 (T  (None, 8)                    0         ['tf.math.multiply_44[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_45[0][0]']
#
#  dense_48 (Dense)            (None, 8)                    72        ['tf.__operators__.add_22[0][0
#                                                                     ]']
#
#  dense_47 (Dense)            (None, 8)                    72        ['tf.__operators__.add_22[0][0
#                                                                     ]']
#
#  tf.math.subtract_23 (TFOpL  (None, 8)                    0         ['dense_48[0][0]']
#  ambda)
#
#  tf.math.multiply_46 (TFOpL  (None, 8)                    0         ['dense_47[0][0]',
#  ambda)                                                              'dense_48[0][0]']
#
#  tf.math.multiply_47 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_22[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_23[0][0]']
#
#  tf.__operators__.add_23 (T  (None, 8)                    0         ['tf.math.multiply_46[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_47[0][0]']
#
#  dense_50 (Dense)            (None, 8)                    72        ['tf.__operators__.add_23[0][0
#                                                                     ]']
#
#  dense_49 (Dense)            (None, 8)                    72        ['tf.__operators__.add_23[0][0
#                                                                     ]']
#
#  tf.math.subtract_24 (TFOpL  (None, 8)                    0         ['dense_50[0][0]']
#  ambda)
#
#  tf.math.multiply_48 (TFOpL  (None, 8)                    0         ['dense_49[0][0]',
#  ambda)                                                              'dense_50[0][0]']
#
#  tf.math.multiply_49 (TFOpL  (None, 8)                    0         ['tf.__operators__.add_23[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.subtract_24[0][0]']
#
#  tf.__operators__.add_24 (T  (None, 8)                    0         ['tf.math.multiply_48[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_49[0][0]']
#
#  dense_52 (Dense)            (None, 8)                    72        ['tf.__operators__.add_24[0][0
#                                                                     ]']
#
#  dense_51 (Dense)            (None, 8)                    72        ['tf.__operators__.add_24[0][0
#                                                                     ]']
#
#  tf.math.subtract_25 (TFOpL  (None, 8)                    0         ['dense_52[0][0]']
#  ambda)
# ...
#
#  tf.__operators__.add_151 (  (None, 8)                    0         ['tf.math.multiply_302[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_303[0][0]']
#
#  dense_306 (Dense)           (None, 8)                    72        ['tf.__operators__.add_151[0][
#                                                                     0]']
#
#  dense_305 (Dense)           (None, 8)                    72        ['tf.__operators__.add_151[0][
#                                                                     0]']
#
#  tf.math.subtract_152 (TFOp  (None, 8)                    0         ['dense_306[0][0]']
#  Lambda)
#
#  tf.math.multiply_304 (TFOp  (None, 8)                    0         ['dense_305[0][0]',
#  Lambda)                                                             'dense_306[0][0]']
#
#  tf.math.multiply_305 (TFOp  (None, 8)                    0         ['tf.__operators__.add_151[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_152[0][0]']
#
#  tf.__operators__.add_152 (  (None, 8)                    0         ['tf.math.multiply_304[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_305[0][0]']
#
#  dense_308 (Dense)           (None, 8)                    72        ['tf.__operators__.add_152[0][
#                                                                     0]']
#
#  dense_307 (Dense)           (None, 8)                    72        ['tf.__operators__.add_152[0][
#                                                                     0]']
#
#  tf.math.subtract_153 (TFOp  (None, 8)                    0         ['dense_308[0][0]']
#  Lambda)
#
#  tf.math.multiply_306 (TFOp  (None, 8)                    0         ['dense_307[0][0]',
#  Lambda)                                                             'dense_308[0][0]']
#
#  tf.math.multiply_307 (TFOp  (None, 8)                    0         ['tf.__operators__.add_152[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_153[0][0]']
#
#  tf.__operators__.add_153 (  (None, 8)                    0         ['tf.math.multiply_306[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_307[0][0]']
#
#  dense_310 (Dense)           (None, 8)                    72        ['tf.__operators__.add_153[0][
#                                                                     0]']
#
#  dense_309 (Dense)           (None, 8)                    72        ['tf.__operators__.add_153[0][
#                                                                     0]']
#
#  tf.math.subtract_154 (TFOp  (None, 8)                    0         ['dense_310[0][0]']
#  Lambda)
#
#  tf.math.multiply_308 (TFOp  (None, 8)                    0         ['dense_309[0][0]',
#  Lambda)                                                             'dense_310[0][0]']
#
#  tf.math.multiply_309 (TFOp  (None, 8)                    0         ['tf.__operators__.add_153[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_154[0][0]']
#
#  tf.__operators__.add_154 (  (None, 8)                    0         ['tf.math.multiply_308[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_309[0][0]']
#
#  dense_312 (Dense)           (None, 8)                    72        ['tf.__operators__.add_154[0][
#                                                                     0]']
#
#  dense_311 (Dense)           (None, 8)                    72        ['tf.__operators__.add_154[0][
#                                                                     0]']
#
#  tf.math.subtract_155 (TFOp  (None, 8)                    0         ['dense_312[0][0]']
#  Lambda)
#
#  tf.math.multiply_310 (TFOp  (None, 8)                    0         ['dense_311[0][0]',
#  Lambda)                                                             'dense_312[0][0]']
#
#  tf.math.multiply_311 (TFOp  (None, 8)                    0         ['tf.__operators__.add_154[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_155[0][0]']
#
#  tf.__operators__.add_155 (  (None, 8)                    0         ['tf.math.multiply_310[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_311[0][0]']
#
#  dense_314 (Dense)           (None, 8)                    72        ['tf.__operators__.add_155[0][
#                                                                     0]']
#
#  dense_313 (Dense)           (None, 8)                    72        ['tf.__operators__.add_155[0][
#                                                                     0]']
#
#  tf.math.subtract_156 (TFOp  (None, 8)                    0         ['dense_314[0][0]']
#  Lambda)
#
#  tf.math.multiply_312 (TFOp  (None, 8)                    0         ['dense_313[0][0]',
#  Lambda)                                                             'dense_314[0][0]']
#
#  tf.math.multiply_313 (TFOp  (None, 8)                    0         ['tf.__operators__.add_155[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_156[0][0]']
#
#  tf.__operators__.add_156 (  (None, 8)                    0         ['tf.math.multiply_312[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_313[0][0]']
#
#  dense_316 (Dense)           (None, 8)                    72        ['tf.__operators__.add_156[0][
#                                                                     0]']
#
#  dense_315 (Dense)           (None, 8)                    72        ['tf.__operators__.add_156[0][
#                                                                     0]']
#
#  tf.math.subtract_157 (TFOp  (None, 8)                    0         ['dense_316[0][0]']
#  Lambda)
#
#  tf.math.multiply_314 (TFOp  (None, 8)                    0         ['dense_315[0][0]',
#  Lambda)                                                             'dense_316[0][0]']
#
#  tf.math.multiply_315 (TFOp  (None, 8)                    0         ['tf.__operators__.add_156[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_157[0][0]']
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  dense_400 (Dense)           (None, 8)                    72        ['tf.__operators__.add_198[0][
#                                                                     0]']
#
#  dense_399 (Dense)           (None, 8)                    72        ['tf.__operators__.add_198[0][
#                                                                     0]']
#
#  tf.math.subtract_199 (TFOp  (None, 8)                    0         ['dense_400[0][0]']
#  Lambda)
#
#  tf.math.multiply_398 (TFOp  (None, 8)                    0         ['dense_399[0][0]',
#  Lambda)                                                             'dense_400[0][0]']
#
#  tf.math.multiply_399 (TFOp  (None, 8)                    0         ['tf.__operators__.add_198[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_199[0][0]']
#
#  tf.__operators__.add_199 (  (None, 8)                    0         ['tf.math.multiply_398[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_399[0][0]']
#
#  dense_402 (Dense)           (None, 8)                    72        ['tf.__operators__.add_199[0][
#                                                                     0]']
#
#  dense_401 (Dense)           (None, 8)                    72        ['tf.__operators__.add_199[0][
#                                                                     0]']
#
#  tf.math.subtract_200 (TFOp  (None, 8)                    0         ['dense_402[0][0]']
#  Lambda)
#
#  tf.math.multiply_400 (TFOp  (None, 8)                    0         ['dense_401[0][0]',
#  Lambda)                                                             'dense_402[0][0]']
#
#  tf.math.multiply_401 (TFOp  (None, 8)                    0         ['tf.__operators__.add_199[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.subtract_200[0][0]']
#
#  tf.__operators__.add_200 (  (None, 8)                    0         ['tf.math.multiply_400[0][0]',
#  TFOpLambda)                                                         'tf.math.multiply_401[0][0]']
#
#  dense_403 (Dense)           (None, 10)                   90        ['tf.__operators__.add_200[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 35314 (137.95 KB)
# Trainable params: 35314 (137.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# 1209 layers

# %% [markdown]
# #### Addestramento del modello

# %%
history = model.fit(
    x=train_images,
    y=train_labels,
    epochs=10,
    batch_size=1024,
    validation_data=(
        test_images,
        test_labels
    )
)
# Out:
# 59/59 [==============================] - 124s 290ms/step - loss: 1.7911 - accuracy: 0.4544 - val_loss: 1.3774 - val_accuracy: 0.6109
# Epoch 2/10
# 59/59 [==============================] - 8s 142ms/step - loss: 1.1146 - accuracy: 0.7006 - val_loss: 0.8652 - val_accuracy: 0.7890
# Epoch 3/10
# 59/59 [==============================] - 7s 126ms/step - loss: 0.6948 - accuracy: 0.8309 - val_loss: 0.5330 - val_accuracy: 0.8619
# Epoch 4/10
# 59/59 [==============================] - 7s 126ms/step - loss: 0.4758 - accuracy: 0.8748 - val_loss: 0.4141 - val_accuracy: 0.8889
# Epoch 5/10
# 59/59 [==============================] - 8s 130ms/step - loss: 0.3901 - accuracy: 0.8924 - val_loss: 0.3594 - val_accuracy: 0.9003
# Epoch 6/10
# 59/59 [==============================] - 7s 127ms/step - loss: 0.3447 - accuracy: 0.9042 - val_loss: 0.3219 - val_accuracy: 0.9108
# Epoch 7/10
# 59/59 [==============================] - 7s 125ms/step - loss: 0.3141 - accuracy: 0.9117 - val_loss: 0.3039 - val_accuracy: 0.9161
# Epoch 8/10
# 59/59 [==============================] - 7s 127ms/step - loss: 0.2918 - accuracy: 0.9165 - val_loss: 0.2873 - val_accuracy: 0.9206
# Epoch 9/10
# 59/59 [==============================] - 7s 125ms/step - loss: 0.2726 - accuracy: 0.9221 - val_loss: 0.2745 - val_accuracy: 0.9238
# Epoch 10/10
# 59/59 [==============================] - 7s 126ms/step - loss: 0.2578 - accuracy: 0.9262 - val_loss: 0.2621 - val_accuracy: 0.9272
